# %% [markdown]
# <a href="https://colab.research.google.com/github/kill100001198/10714/blob/main/20260901.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("안녕하세요.")
print("방갑습니다.")
print("저는 이성찬입니다.")
# Out:
# 안녕하세요.
# 방갑습니다.
# 저는 이성찬입니다.
