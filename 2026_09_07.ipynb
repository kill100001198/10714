# %% [markdown]
# <a href="https://colab.research.google.com/github/kill100001198/10714/blob/main/2026_09_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
from datetime import datetime, date,time

# %%
now=datetime.now()
print(now)
# Out:
# 2026-09-07 00:00:47.481017

# %%
print('<디데이(D-day)프로그램>')
print()
year= int(input('연도를 입력하세요:'))
month= int(input('월을 입력하세요.'))
day =  int(input ('일을 입력 하세요'))
dt4 = date(year,month, day)
today=date.today( )
dday =(dt4 - today).days
print(f'{year}년 {month}월 {day}일은 {dday}일 남았습니다.')
# Out:
# <디데이(D-day)프로그램>
#
# 연도를 입력하세요:2026
# 월을 입력하세요.10
# 일을 입력 하세요4
# 2026년 10월 4일은 27일 남았습니다.

# %%
print('회전초밥 영수증')
red=1000
