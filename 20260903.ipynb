# %% [markdown]
# <a href="https://colab.research.google.com/github/kill100001198/10714/blob/main/20260903.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('재미있는 프로그래밍')
print(3+7)
print('3+7')
print(10,20,30,'정보', '프로그래밍')

# %%
print ('한양과학기술고등학교','1학년','이성찬')
print ('체질량 지수(BMI):', 60/(170 * 170)*10000)

# %%
print(f'현재 온도는 {20}도 입니다')

# %%
a=20
b=50
print('현재 온도는 %d도, 습도는 %d%% 입니다.'%(a,b))
print('현재 온도는 {}도, 습도는 {}% 입니다.'.format(a,b))

# %%
a=90
b=3.141592
print('직각은 {0}도, 원주율은 {1:0.2f}입니다.'.format(a,b))

# %%
print('동해 물과\'백두산\'이')
print('동해 물과\"백두산\"이')
print('마르고 닳도록')
print('하느님이 보우하사 \n우리나라 만세')
print('화려 강산')
print('대한사람,"대한"으로 길이 보전하세.')
print('2026','09','03',sep='-')
# Out:
# 동해 물과'백두산'이
# 동해 물과"백두산"이
# 마르고 닳도록
# 하느님이 보우하사
# 우리나라 만세
# 화려 강산
# 대한사람,"대한"으로 길이 보전하세.
# 2026-09-03

# %%
print('품목\t\t가격\t\t개수\n사과\t\t2,000\t\t8\n바나나\t\t3,000\t\t5')
# Out:
# 품목		가격		개수
# 사과		2,000		8
# 바나나		3,000		5
