# %% [markdown]
# <a href="https://colab.research.google.com/github/kill100001198/10714/blob/main/20260910.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=6
b=1.5
c=1+2j
(print(a+1))
(print(a/b))
(print(a/2))
(print(a//2))
(print(c+a+3))
# Out:
# 7
# 4.0
# 3.0
# 3
# (10+2j)

# %%
a='Hello'
b=''
c=10
d=0
print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
# Out:
# True
# False
# True
# False

# %%
a='100'
b='python'
c='name is 짱구'
d='name is  코난'
print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
# Out:
# True
# True
# True
# True

# %%
a='hello'
b='world'
print(a+b)
print(a*3)
print(a<b) #두 문자열 을 사전순(알파벳순/아스키코드값)으로 비교
print('h' in a)
print('wor'not in b)
# Out:
# helloworld
# hellohellohello
# True
# True
# False

# %%
#한 문자만 인덱싱 : 변수명[인덱스 번호]
a='hello python'
print(a[0])
print(a[6])
print(a[-1])
# Out:
# h
# p
# n

# %%
a='hello python'
print(a[0:5]) #0~4
print(a[6:])  #6~끝
print(a[:5])  #0~4
print(a[6:-4])#6~끝에서 5번째
print(a[0:9:2])#0~8(2칸간격)
# Out:
# hello
# python
# hello
# py
# hlopt

# %%
a = int(input("주민번호를 찍으세요 : "))
print(a[0:4])
# Out:
# 주민번호를 찍으세요 : 10022430150015
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1127/725851782.py in <cell line: 0>()
#       1 a = int(input("주민번호를 찍으세요 : "))
# ----> 2 print(a[0:4])
#
# TypeError: 'int' object is not subscriptable
